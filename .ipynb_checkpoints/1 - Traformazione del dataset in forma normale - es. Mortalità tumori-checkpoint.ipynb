# %%
# ---------------------------------------------------------------
# python importa la libreria OS che controlla il sistema operativo
import os 
# ---------------------------------------------------------------
# python importa la libreria Pandas che permette l'importazione ed analisi dei dati: potrà essere richiamata come PD
import pandas as pd 

#importo le librerie di visualizzazione dei grafici
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt

# %%
# scelgo un dataset da "indice dei dataset bes.html"

# copiare dopo il segno "=" la posizione del dataset (vedi "indice dei dataset bes.html)  
posizione_del_dataset = os.path.join(os.getcwd(), "Appendice-statistica-2016", "01.Salute", "Cap_01_Salute 07.xlsx")
# copia dopo il segno "=" il nome del foglio di calcolo
nome_del_foglio = 'REG totale'

# %%
#scelto un file excel si verifica che tutto sia stato compilato correttamente e,in caso negativo si consiglia come correggere l'errore
try:
    dati = pd.read_excel(posizione_del_dataset, sheetname = nome_del_foglio)
except:
    dati = pd.read_excel(posizione_del_dataset, sheetname = None)
    #print(list(dati.keys()))
    print("c'è un problema con il foglio selezionato: riprova selezionando il nome del foglio fra questi nella cella precedente: {}".format(list(dati.keys())))

# %%
dati
# Out:
#                                            Unnamed: 0   Unnamed: 1  \
# 0                                                 NaN          NaN
# 1   Tavola 7.1 segue - Tasso standardizzato di mor...          NaN
# 2                                   ripartizione g...          NaN
# 3                                                 NaN          NaN
# 4               REGIONI E \nRIPARTIZIONI\nGEOGRAFICHE  2006.000000
# 5                                                 NaN          NaN
# 6                                                 NaN          NaN
# 7                                                 NaN          NaN
# 8                                                 NaN          NaN
# 9                                    MASCHI E FEMMINE          NaN
# 10                                                NaN          NaN
# 11                                           Piemonte    10.473993
# 12                       Valle d'Aosta/Vallée d'Aoste    10.083149
# 13                                            Liguria    10.037698
# 14                                          Lombardia    10.624125
# 15                       Trentino-Alto Adige/Südtirol     9.343514
# 16                                      Bolzano/Bozen     9.196930
# 17                                             Trento     9.515634
# 18                                             Veneto     9.857299
# 19                              Friuli-Venezia Giulia    11.134162
# 20                                     Emilia-Romagna     9.732584
# 21                                            Toscana     9.786658
# 22                                             Umbria     9.038523
# 23                                             Marche     8.762876
# 24                                              Lazio     9.961727
# 25                                            Abruzzo     8.279345
# 26                                             Molise     9.132241
# 27                                           Campania    10.738863
# 28                                             Puglia     9.251814
# 29                                         Basilicata     8.403515
# 30                                           Calabria     8.221943
# 31                                            Sicilia     9.287140
# 32                                           Sardegna    10.953107
# 33                                               Nord    10.269398
# 34                                            Centro      9.676437
# 35                                        Mezzogiorno     9.628114
# 36                                             Italia     9.943193
# 37                                                NaN          NaN
# 38                                                NaN          NaN
# 39  Fonte: Per i decessi: Istat,  Indagine sui dec...          NaN
# 40          sesso, anno di nascita e stato civile\n\n          NaN
#
#      Unnamed: 2   Unnamed: 3   Unnamed: 4   Unnamed: 5   Unnamed: 6  \
# 0           NaN          NaN          NaN          NaN          NaN
# 1           NaN          NaN          NaN          NaN          NaN
# 2           NaN          NaN          NaN          NaN          NaN
# 3           NaN          NaN          NaN          NaN          NaN
# 4   2007.000000  2008.000000  2009.000000  2010.000000  2011.000000
# 5           NaN          NaN          NaN          NaN          NaN
# 6           NaN          NaN          NaN          NaN          NaN
# 7           NaN          NaN          NaN          NaN          NaN
# 8           NaN          NaN          NaN          NaN          NaN
# 9           NaN          NaN          NaN          NaN          NaN
# 10          NaN          NaN          NaN          NaN          NaN
# 11     9.811620     9.706195     9.811948     9.630095     9.520942
# 12    12.999488    10.134989     8.245396     9.186476     9.581953
# 13     9.349132    10.341580    10.268055     8.900869     9.426247
# 14    10.337121     9.803250     9.878224     9.399147     9.136209
# 15     8.920976     8.606164     8.520739     8.701271     8.194145
# 16     8.366135     8.340498     8.282314     8.480910     7.444230
# 17     9.437965     8.844756     8.739986     8.907709     8.833475
# 18     9.304258     9.521597     8.752798     8.442298     8.552059
# 19    10.519679    10.830987     9.782200     9.544819     9.834176
# 20     9.496995     8.754444     9.041765     8.928819     8.624951
# 21     9.446584     9.490376     9.038616     8.797349     8.262912
# 22     9.585545     9.277928     8.826050     8.471056     8.402183
# 23     8.318285     9.413769     8.881703     8.416898     8.602794
# 24     9.940054     9.829749     9.693826     9.715792     9.441675
# 25     8.317963     8.041528     8.333686     8.132791     8.260933
# 26     8.279703     8.862326     9.487961     8.767289     8.207210
# 27    11.132591    10.437188    10.400332    10.349058    10.127504
# 28     9.004357     9.080350     8.607182     8.460603     8.481732
# 29     8.809508     7.568217     8.811392     7.578462     8.307434
# 30     8.516019     8.491426     9.083340     8.376114     8.402519
# 31     9.743120     9.362717     9.292084     8.906136     9.153063
# 32     9.888973    10.000111    10.225423     9.800913    10.217581
# 33     9.848322     9.613142     9.498639     9.141661     9.031967
# 34     9.542079     9.626902     9.304731     9.157250     8.874971
# 35     9.729837     9.428926     9.443549     9.144703     9.206021
# 36     9.752770     9.557722     9.444983     9.144227     9.059653
# 37          NaN          NaN          NaN          NaN          NaN
# 38          NaN          NaN          NaN          NaN          NaN
# 39          NaN          NaN          NaN          NaN          NaN
# 40          NaN          NaN          NaN          NaN          NaN
#
#      Unnamed: 7   Unnamed: 8
# 0           NaN          NaN
# 1           NaN          NaN
# 2           NaN          NaN
# 3           NaN          NaN
# 4   2012.000000  2013.000000
# 5           NaN          NaN
# 6           NaN          NaN
# 7           NaN          NaN
# 8           NaN          NaN
# 9           NaN          NaN
# 10          NaN          NaN
# 11     9.070903     8.810412
# 12     9.018351     8.210124
# 13     9.228392     8.567550
# 14     9.035430     8.438940
# 15     8.410071     7.802517
# 16     8.164193     7.834943
# 17     8.622358     7.789117
# 18     8.563221     7.997452
# 19     9.372356     9.097870
# 20     8.397621     8.086747
# 21     8.592467     8.146569
# 22     8.730052     7.937233
# 23     8.280489     8.642410
# 24     9.529682     9.035600
# 25     7.759250     7.751787
# 26     7.984725     7.716547
# 27    10.045993    10.004526
# 28     8.235239     8.526751
# 29     7.795767     8.462638
# 30     8.191673     7.607723
# 31     8.898371     8.841627
# 32    10.107256    10.037771
# 33     8.860580     8.376579
# 34     9.006801     8.618761
# 35     8.994938     8.983989
# 36     8.933427     8.631629
# 37          NaN          NaN
# 38          NaN          NaN
# 39          NaN          NaN
# 40          NaN          NaN

# %%
print(dati.iloc[1,0])
titolo = dati.iloc[1,0]
# Out:
# Tavola 7.1 segue - Tasso standardizzato di mortalità per tumore per le persone di 20-64 anni per sesso, regione e

# %%
#individua la riga corrispondente all'intestazione di colonna e inserisci il valore 
intestazione_colonna = 4 #ATTENZIONE, MODIFICARE QUESTO VALORE SE NON CORRISPONDE.. lo vedete dall'intestazione di colonna
dati.columns = dati.loc[intestazione_colonna]
dati.drop(intestazione_colonna, inplace = True)
dati
# Out:
# 4               REGIONI E \nRIPARTIZIONI\nGEOGRAFICHE     2006.0     2007.0  \
# 0                                                 NaN        NaN        NaN
# 1   Tavola 7.1 segue - Tasso standardizzato di mor...        NaN        NaN
# 2                                   ripartizione g...        NaN        NaN
# 3                                                 NaN        NaN        NaN
# 5                                                 NaN        NaN        NaN
# 6                                                 NaN        NaN        NaN
# 7                                                 NaN        NaN        NaN
# 8                                                 NaN        NaN        NaN
# 9                                    MASCHI E FEMMINE        NaN        NaN
# 10                                                NaN        NaN        NaN
# 11                                           Piemonte  10.473993   9.811620
# 12                       Valle d'Aosta/Vallée d'Aoste  10.083149  12.999488
# 13                                            Liguria  10.037698   9.349132
# 14                                          Lombardia  10.624125  10.337121
# 15                       Trentino-Alto Adige/Südtirol   9.343514   8.920976
# 16                                      Bolzano/Bozen   9.196930   8.366135
# 17                                             Trento   9.515634   9.437965
# 18                                             Veneto   9.857299   9.304258
# 19                              Friuli-Venezia Giulia  11.134162  10.519679
# 20                                     Emilia-Romagna   9.732584   9.496995
# 21                                            Toscana   9.786658   9.446584
# 22                                             Umbria   9.038523   9.585545
# 23                                             Marche   8.762876   8.318285
# 24                                              Lazio   9.961727   9.940054
# 25                                            Abruzzo   8.279345   8.317963
# 26                                             Molise   9.132241   8.279703
# 27                                           Campania  10.738863  11.132591
# 28                                             Puglia   9.251814   9.004357
# 29                                         Basilicata   8.403515   8.809508
# 30                                           Calabria   8.221943   8.516019
# 31                                            Sicilia   9.287140   9.743120
# 32                                           Sardegna  10.953107   9.888973
# 33                                               Nord  10.269398   9.848322
# 34                                            Centro    9.676437   9.542079
# 35                                        Mezzogiorno   9.628114   9.729837
# 36                                             Italia   9.943193   9.752770
# 37                                                NaN        NaN        NaN
# 38                                                NaN        NaN        NaN
# 39  Fonte: Per i decessi: Istat,  Indagine sui dec...        NaN        NaN
# 40          sesso, anno di nascita e stato civile\n\n        NaN        NaN
#
# 4      2008.0     2009.0     2010.0     2011.0     2012.0     2013.0
# 0         NaN        NaN        NaN        NaN        NaN        NaN
# 1         NaN        NaN        NaN        NaN        NaN        NaN
# 2         NaN        NaN        NaN        NaN        NaN        NaN
# 3         NaN        NaN        NaN        NaN        NaN        NaN
# 5         NaN        NaN        NaN        NaN        NaN        NaN
# 6         NaN        NaN        NaN        NaN        NaN        NaN
# 7         NaN        NaN        NaN        NaN        NaN        NaN
# 8         NaN        NaN        NaN        NaN        NaN        NaN
# 9         NaN        NaN        NaN        NaN        NaN        NaN
# 10        NaN        NaN        NaN        NaN        NaN        NaN
# 11   9.706195   9.811948   9.630095   9.520942   9.070903   8.810412
# 12  10.134989   8.245396   9.186476   9.581953   9.018351   8.210124
# 13  10.341580  10.268055   8.900869   9.426247   9.228392   8.567550
# 14   9.803250   9.878224   9.399147   9.136209   9.035430   8.438940
# 15   8.606164   8.520739   8.701271   8.194145   8.410071   7.802517
# 16   8.340498   8.282314   8.480910   7.444230   8.164193   7.834943
# 17   8.844756   8.739986   8.907709   8.833475   8.622358   7.789117
# 18   9.521597   8.752798   8.442298   8.552059   8.563221   7.997452
# 19  10.830987   9.782200   9.544819   9.834176   9.372356   9.097870
# 20   8.754444   9.041765   8.928819   8.624951   8.397621   8.086747
# 21   9.490376   9.038616   8.797349   8.262912   8.592467   8.146569
# 22   9.277928   8.826050   8.471056   8.402183   8.730052   7.937233
# 23   9.413769   8.881703   8.416898   8.602794   8.280489   8.642410
# 24   9.829749   9.693826   9.715792   9.441675   9.529682   9.035600
# 25   8.041528   8.333686   8.132791   8.260933   7.759250   7.751787
# 26   8.862326   9.487961   8.767289   8.207210   7.984725   7.716547
# 27  10.437188  10.400332  10.349058  10.127504  10.045993  10.004526
# 28   9.080350   8.607182   8.460603   8.481732   8.235239   8.526751
# 29   7.568217   8.811392   7.578462   8.307434   7.795767   8.462638
# 30   8.491426   9.083340   8.376114   8.402519   8.191673   7.607723
# 31   9.362717   9.292084   8.906136   9.153063   8.898371   8.841627
# 32  10.000111  10.225423   9.800913  10.217581  10.107256  10.037771
# 33   9.613142   9.498639   9.141661   9.031967   8.860580   8.376579
# 34   9.626902   9.304731   9.157250   8.874971   9.006801   8.618761
# 35   9.428926   9.443549   9.144703   9.206021   8.994938   8.983989
# 36   9.557722   9.444983   9.144227   9.059653   8.933427   8.631629
# 37        NaN        NaN        NaN        NaN        NaN        NaN
# 38        NaN        NaN        NaN        NaN        NaN        NaN
# 39        NaN        NaN        NaN        NaN        NaN        NaN
# 40        NaN        NaN        NaN        NaN        NaN        NaN

# %%
#rimuovi le righe senza valori oppure con dati esterni alla tabella
dati.dropna(axis = 1, inplace = True, how = "all")
dati.dropna(inplace = True)
dati
# Out:
# 4  REGIONI E \nRIPARTIZIONI\nGEOGRAFICHE     2006.0     2007.0     2008.0  \
# 11                              Piemonte  10.473993   9.811620   9.706195
# 12          Valle d'Aosta/Vallée d'Aoste  10.083149  12.999488  10.134989
# 13                               Liguria  10.037698   9.349132  10.341580
# 14                             Lombardia  10.624125  10.337121   9.803250
# 15          Trentino-Alto Adige/Südtirol   9.343514   8.920976   8.606164
# 16                         Bolzano/Bozen   9.196930   8.366135   8.340498
# 17                                Trento   9.515634   9.437965   8.844756
# 18                                Veneto   9.857299   9.304258   9.521597
# 19                 Friuli-Venezia Giulia  11.134162  10.519679  10.830987
# 20                        Emilia-Romagna   9.732584   9.496995   8.754444
# 21                               Toscana   9.786658   9.446584   9.490376
# 22                                Umbria   9.038523   9.585545   9.277928
# 23                                Marche   8.762876   8.318285   9.413769
# 24                                 Lazio   9.961727   9.940054   9.829749
# 25                               Abruzzo   8.279345   8.317963   8.041528
# 26                                Molise   9.132241   8.279703   8.862326
# 27                              Campania  10.738863  11.132591  10.437188
# 28                                Puglia   9.251814   9.004357   9.080350
# 29                            Basilicata   8.403515   8.809508   7.568217
# 30                              Calabria   8.221943   8.516019   8.491426
# 31                               Sicilia   9.287140   9.743120   9.362717
# 32                              Sardegna  10.953107   9.888973  10.000111
# 33                                  Nord  10.269398   9.848322   9.613142
# 34                               Centro    9.676437   9.542079   9.626902
# 35                           Mezzogiorno   9.628114   9.729837   9.428926
# 36                                Italia   9.943193   9.752770   9.557722
#
# 4      2009.0     2010.0     2011.0     2012.0     2013.0
# 11   9.811948   9.630095   9.520942   9.070903   8.810412
# 12   8.245396   9.186476   9.581953   9.018351   8.210124
# 13  10.268055   8.900869   9.426247   9.228392   8.567550
# 14   9.878224   9.399147   9.136209   9.035430   8.438940
# 15   8.520739   8.701271   8.194145   8.410071   7.802517
# 16   8.282314   8.480910   7.444230   8.164193   7.834943
# 17   8.739986   8.907709   8.833475   8.622358   7.789117
# 18   8.752798   8.442298   8.552059   8.563221   7.997452
# 19   9.782200   9.544819   9.834176   9.372356   9.097870
# 20   9.041765   8.928819   8.624951   8.397621   8.086747
# 21   9.038616   8.797349   8.262912   8.592467   8.146569
# 22   8.826050   8.471056   8.402183   8.730052   7.937233
# 23   8.881703   8.416898   8.602794   8.280489   8.642410
# 24   9.693826   9.715792   9.441675   9.529682   9.035600
# 25   8.333686   8.132791   8.260933   7.759250   7.751787
# 26   9.487961   8.767289   8.207210   7.984725   7.716547
# 27  10.400332  10.349058  10.127504  10.045993  10.004526
# 28   8.607182   8.460603   8.481732   8.235239   8.526751
# 29   8.811392   7.578462   8.307434   7.795767   8.462638
# 30   9.083340   8.376114   8.402519   8.191673   7.607723
# 31   9.292084   8.906136   9.153063   8.898371   8.841627
# 32  10.225423   9.800913  10.217581  10.107256  10.037771
# 33   9.498639   9.141661   9.031967   8.860580   8.376579
# 34   9.304731   9.157250   8.874971   9.006801   8.618761
# 35   9.443549   9.144703   9.206021   8.994938   8.983989
# 36   9.444983   9.144227   9.059653   8.933427   8.631629

# %%
#individua la colonna relativa all'indice di riga (casi)
print(dati.columns)
# Out:
# Index(['REGIONI E \nRIPARTIZIONI\nGEOGRAFICHE',
#                                         2006.0,
#                                         2007.0,
#                                         2008.0,
#                                         2009.0,
#                                         2010.0,
#                                         2011.0,
#                                         2012.0,
#                                         2013.0],
#       dtype='object', name=4)

# %%
#estrai sotto tabella (es. maschi o femmine)
#dati = dati.loc[:35]
#dati

# %%
indice_di_riga = 'REGIONI E \nRIPARTIZIONI\nGEOGRAFICHE'
dati.set_index(indice_di_riga, inplace = True)
dati
# Out:
# 4                                         2006.0     2007.0     2008.0  \
# REGIONI E \nRIPARTIZIONI\nGEOGRAFICHE
# Piemonte                               10.473993   9.811620   9.706195
# Valle d'Aosta/Vallée d'Aoste           10.083149  12.999488  10.134989
# Liguria                                10.037698   9.349132  10.341580
# Lombardia                              10.624125  10.337121   9.803250
# Trentino-Alto Adige/Südtirol            9.343514   8.920976   8.606164
# Bolzano/Bozen                           9.196930   8.366135   8.340498
# Trento                                  9.515634   9.437965   8.844756
# Veneto                                  9.857299   9.304258   9.521597
# Friuli-Venezia Giulia                  11.134162  10.519679  10.830987
# Emilia-Romagna                          9.732584   9.496995   8.754444
# Toscana                                 9.786658   9.446584   9.490376
# Umbria                                  9.038523   9.585545   9.277928
# Marche                                  8.762876   8.318285   9.413769
# Lazio                                   9.961727   9.940054   9.829749
# Abruzzo                                 8.279345   8.317963   8.041528
# Molise                                  9.132241   8.279703   8.862326
# Campania                               10.738863  11.132591  10.437188
# Puglia                                  9.251814   9.004357   9.080350
# Basilicata                              8.403515   8.809508   7.568217
# Calabria                                8.221943   8.516019   8.491426
# Sicilia                                 9.287140   9.743120   9.362717
# Sardegna                               10.953107   9.888973  10.000111
# Nord                                   10.269398   9.848322   9.613142
# Centro                                  9.676437   9.542079   9.626902
# Mezzogiorno                             9.628114   9.729837   9.428926
# Italia                                  9.943193   9.752770   9.557722
#
# 4                                         2009.0     2010.0     2011.0  \
# REGIONI E \nRIPARTIZIONI\nGEOGRAFICHE
# Piemonte                                9.811948   9.630095   9.520942
# Valle d'Aosta/Vallée d'Aoste            8.245396   9.186476   9.581953
# Liguria                                10.268055   8.900869   9.426247
# Lombardia                               9.878224   9.399147   9.136209
# Trentino-Alto Adige/Südtirol            8.520739   8.701271   8.194145
# Bolzano/Bozen                           8.282314   8.480910   7.444230
# Trento                                  8.739986   8.907709   8.833475
# Veneto                                  8.752798   8.442298   8.552059
# Friuli-Venezia Giulia                   9.782200   9.544819   9.834176
# Emilia-Romagna                          9.041765   8.928819   8.624951
# Toscana                                 9.038616   8.797349   8.262912
# Umbria                                  8.826050   8.471056   8.402183
# Marche                                  8.881703   8.416898   8.602794
# Lazio                                   9.693826   9.715792   9.441675
# Abruzzo                                 8.333686   8.132791   8.260933
# Molise                                  9.487961   8.767289   8.207210
# Campania                               10.400332  10.349058  10.127504
# Puglia                                  8.607182   8.460603   8.481732
# Basilicata                              8.811392   7.578462   8.307434
# Calabria                                9.083340   8.376114   8.402519
# Sicilia                                 9.292084   8.906136   9.153063
# Sardegna                               10.225423   9.800913  10.217581
# Nord                                    9.498639   9.141661   9.031967
# Centro                                  9.304731   9.157250   8.874971
# Mezzogiorno                             9.443549   9.144703   9.206021
# Italia                                  9.444983   9.144227   9.059653
#
# 4                                         2012.0     2013.0
# REGIONI E \nRIPARTIZIONI\nGEOGRAFICHE
# Piemonte                                9.070903   8.810412
# Valle d'Aosta/Vallée d'Aoste            9.018351   8.210124
# Liguria                                 9.228392   8.567550
# Lombardia                               9.035430   8.438940
# Trentino-Alto Adige/Südtirol            8.410071   7.802517
# Bolzano/Bozen                           8.164193   7.834943
# Trento                                  8.622358   7.789117
# Veneto                                  8.563221   7.997452
# Friuli-Venezia Giulia                   9.372356   9.097870
# Emilia-Romagna                          8.397621   8.086747
# Toscana                                 8.592467   8.146569
# Umbria                                  8.730052   7.937233
# Marche                                  8.280489   8.642410
# Lazio                                   9.529682   9.035600
# Abruzzo                                 7.759250   7.751787
# Molise                                  7.984725   7.716547
# Campania                               10.045993  10.004526
# Puglia                                  8.235239   8.526751
# Basilicata                              7.795767   8.462638
# Calabria                                8.191673   7.607723
# Sicilia                                 8.898371   8.841627
# Sardegna                               10.107256  10.037771
# Nord                                    8.860580   8.376579
# Centro                                  9.006801   8.618761
# Mezzogiorno                             8.994938   8.983989
# Italia                                  8.933427   8.631629

# %%
#da questa lista è possibile selezionare un sottoinsieme da visualizzare nel grafico 
dati.index
# Out:
# Index(['Piemonte', 'Valle d'Aosta/Vallée d'Aoste', 'Liguria', 'Lombardia',
#        'Trentino-Alto Adige/Südtirol', 'Bolzano/Bozen', 'Trento', 'Veneto',
#        'Friuli-Venezia Giulia', 'Emilia-Romagna', 'Toscana', 'Umbria',
#        'Marche', 'Lazio', 'Abruzzo', 'Molise', 'Campania', 'Puglia',
#        'Basilicata', 'Calabria', 'Sicilia', 'Sardegna', 'Nord', 'Centro ',
#        'Mezzogiorno', 'Italia'],
#       dtype='object', name='REGIONI E \nRIPARTIZIONI\nGEOGRAFICHE')

# %%
dati.loc[["Nord", "Mezzogiorno", "Centro "]].T.plot(figsize = (20,10), title = titolo) #trasponi la tabella e mostra il grafico

# %%
dati_indice_2002 = dati.divide(dati[dati.columns[0]], axis = 0) * 100

# %%
dati_indice_2002.loc[["Nord", "Mezzogiorno", "Centro "]].T.plot(figsize = (20,10), title = titolo + " numero indice base 100 anno 2006") #trasponi la tabella e mostra il grafico

# %%
#se vogliamo creare un indice addittivo fra più dataset dobbiamo bisogno di portare alla stessa unità di misura i valori 
#attraverso la standardizzazione

# standardizzazione: https://it.wikipedia.org/wiki/Standardizzazione_(statistica)?veaction=edit

# indice addittivo: http://www.federica.unina.it/sociologia/metodologia-e-tecnica-della-ricerca-sociale/la-ricomposizione-degli-indicatori-e-la-costruzione-degli-indici/
