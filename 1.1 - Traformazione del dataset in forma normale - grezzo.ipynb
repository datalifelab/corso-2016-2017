# %%
# ---------------------------------------------------------------
# python importa la libreria OS che controlla il sistema operativo
import os 
# ---------------------------------------------------------------
# python importa la libreria Pandas che permette l'importazione ed analisi dei dati: potrà essere richiamata come PD
import pandas as pd 

#importo le librerie di visualizzazione dei grafici
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt

# %%
# scelgo un dataset da "indice dei dataset bes.html"

# copiare dopo il segno "=" la posizione del dataset (vedi "indice dei dataset bes.html)  
posizione_del_dataset = os.path.join(os.getcwd(), "Appendice-statistica-2016", "04.Benessere economico", "Cap_04_Benessere economico 01.xlsx")
# copia dopo il segno "=" il nome del foglio di calcolo
nome_del_foglio = 'REG totale'

# %%
#scelto un file excel si verifica che tutto sia stato compilato correttamente e,in caso negativo si consiglia come correggere l'errore
try:
    dati = pd.read_excel(posizione_del_dataset, sheetname = nome_del_foglio)
except:
    dati = pd.read_excel(posizione_del_dataset, sheetname = None)
    #print(list(dati.keys()))
    print("c'è un problema con il foglio selezionato: riprova selezionando il nome del foglio fra questi nella cella precedente: {}".format(list(dati.keys())))

# %%
dati
# Out:
#                                            Unnamed: 0    Unnamed: 1  \
# 0                                                 NaN           NaN
# 1   Tavola 1.1 -  Reddito medio disponibile (pro c...           NaN
# 2                                                 NaN           NaN
# 3               REGIONI E \nRIPARTIZIONI\nGEOGRAFICHE   2004.000000
# 4                                                 NaN           NaN
# 5                                                 NaN           NaN
# 6                                                 NaN           NaN
# 7                                                 NaN           NaN
# 8                                                 NaN           NaN
# 9                                            Piemonte  19112.734326
# 10                       Valle d'Aosta/Vallée d'Aoste  19471.810445
# 11                                            Liguria  19480.997332
# 12                                          Lombardia  20415.407205
# ...

# %%
titolo = dati.iloc[1,0]
print(dati.iloc[1,0])
# Out:
# Tavola 1.1 -  Reddito medio disponibile (pro capite) delle famiglie consumatrici - Anni 2004-2015

# %%
#individua la riga corrispondente all'intestazione di colonna e inserisci il valore 
intestazione_colonna = 4 #ATTENZIONE, MODIFICARE QUESTO VALORE SE NON CORRISPONDE.. lo vedete dall'intestazione di colonna
dati.columns = dati.loc[intestazione_colonna]
dati.drop(intestazione_colonna, inplace = True)
dati
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\nicod\Anaconda3\lib\site-packages\pandas\core\indexing.py in _has_valid_type(self, key, axis)
#    1410                 if key not in ax:
# -> 1411                     error()
#    1412             except TypeError as e:
#
# C:\Users\nicod\Anaconda3\lib\site-packages\pandas\core\indexing.py in error()
#    1405                 raise KeyError("the label [%s] is not in the [%s]" %
# -> 1406                                (key, self.obj._get_axis_name(axis)))
#    1407
#
# KeyError: 'the label [4] is not in the [index]'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-a3f8255d9298> in <module>()
#       1 #individua la riga corrispondente all'intestazione di colonna e inserisci il valore
# ...

# %%
#rimuovi le righe senza valori oppure con dati esterni alla tabella
dati.dropna(axis = 1, inplace = True, how = "all")
dati.dropna(inplace = True)
dati

# %%
#individua la colonna relativa all'indice di riga (casi)
print(dati.columns)
# Out:
# Index(['REGIONI E \nRIPARTIZIONI\nGEOGRAFICHE',
#                                         2006.0,
#                                         2007.0,
#                                         2008.0,
#                                         2009.0,
#                                         2010.0,
#                                         2011.0,
#                                         2012.0,
#                                         2013.0],
#       dtype='object', name=4)

# %%
#estrai sotto tabella (es. maschi o femmine)
#dati = dati.loc[:35]
#dati

# %%
indice_di_riga = 'REGIONI E \nRIPARTIZIONI\nGEOGRAFICHE'
dati.set_index(indice_di_riga, inplace = True)
dati
# Out:
# 4                                        2006.0    2007.0    2008.0    2009.0  \
# REGIONI E \nRIPARTIZIONI\nGEOGRAFICHE
# Piemonte                               1.813251  1.671979  1.426445  1.062688
# Valle d'Aosta/Vallée d'Aoste           2.107059  1.992838  2.339968  1.974024
# Liguria                                1.005885  1.000683  0.875718  0.659549
# Lombardia                              1.582811  1.413940  1.293970  1.012633
# Trentino-Alto Adige/Südtirol           1.484505  0.769564  1.203693  1.399049
# Bolzano/Bozen                          1.532809  0.658449  1.168029  1.143081
# Trento                                 1.416168  0.880911  1.215234  1.662847
# Veneto                                 1.586608  1.759951  1.420070  1.038659
# Friuli-Venezia Giulia                  1.835874  1.364575  0.961133  1.151548
# Emilia-Romagna                         1.643606  1.611092  1.606756  1.181290
# ...

# %%
#da questa lista è possibile selezionare un sottoinsieme da visualizzare nel grafico 
dati.index
# Out:
# Index(['Piemonte', 'Valle d'Aosta/Vallée d'Aoste', 'Liguria', 'Lombardia',
#        'Trentino-Alto Adige/Südtirol', 'Bolzano/Bozen', 'Trento', 'Veneto',
#        'Friuli-Venezia Giulia', 'Emilia-Romagna', 'Toscana', 'Umbria',
#        'Marche', 'Lazio', 'Abruzzo', 'Molise', 'Campania', 'Puglia',
#        'Basilicata', 'Calabria', 'Sicilia', 'Sardegna', 'Nord', 'Centro ',
#        'Mezzogiorno', 'Italia'],
#       dtype='object', name='REGIONI E \nRIPARTIZIONI\nGEOGRAFICHE')

# %%
dati.loc[["Nord", "Mezzogiorno", "Centro "]].T.plot(figsize = (20,10), title = titolo) #trasponi la tabella e mostra il grafico

# %%
dati_indice_2002 = dati.divide(dati[dati.columns[0]], axis = 0) * 100

# %%
dati_indice_2002.loc[["Nord", "Mezzogiorno", "Centro "]].T.plot(figsize = (20,10), title = titolo + " - numero indice base 100, anno 2006") #trasponi la tabella e mostra il grafico

# %%
#se vogliamo creare un indice addittivo fra più dataset dobbiamo bisogno di portare alla stessa unità di misura i valori 
#attraverso la standardizzazione

# standardizzazione: https://it.wikipedia.org/wiki/Standardizzazione_(statistica)?veaction=edit

# indice addittivo: http://www.federica.unina.it/sociologia/metodologia-e-tecnica-della-ricerca-sociale/la-ricomposizione-degli-indicatori-e-la-costruzione-degli-indici/

# %%
from sklearn import preprocessing

# %%
dati.index
# Out:
# Index(['Piemonte', 'Valle d'Aosta/Vallée d'Aoste', 'Liguria', 'Lombardia',
#        'Trentino-Alto Adige/Südtirol', 'Bolzano/Bozen', 'Trento', 'Veneto',
#        'Friuli-Venezia Giulia', 'Emilia-Romagna', 'Toscana', 'Umbria',
#        'Marche', 'Lazio', 'Abruzzo', 'Molise', 'Campania', 'Puglia',
#        'Basilicata', 'Calabria', 'Sicilia', 'Sardegna', 'Nord', 'Centro ',
#        'Mezzogiorno', 'Italia'],
#       dtype='object', name='REGIONI E \nRIPARTIZIONI\nGEOGRAFICHE')

# %%
dati_regionale = dati.drop(["Nord", "Centro ", 'Mezzogiorno', "Italia"])
dati_regionale
# Out:
# 4                                        2006.0    2007.0    2008.0    2009.0  \
# REGIONI E \nRIPARTIZIONI\nGEOGRAFICHE
# Piemonte                               1.813251  1.671979  1.426445  1.062688
# Valle d'Aosta/Vallée d'Aoste           2.107059  1.992838  2.339968  1.974024
# Liguria                                1.005885  1.000683  0.875718  0.659549
# Lombardia                              1.582811  1.413940  1.293970  1.012633
# Trentino-Alto Adige/Südtirol           1.484505  0.769564  1.203693  1.399049
# Bolzano/Bozen                          1.532809  0.658449  1.168029  1.143081
# Trento                                 1.416168  0.880911  1.215234  1.662847
# Veneto                                 1.586608  1.759951  1.420070  1.038659
# Friuli-Venezia Giulia                  1.835874  1.364575  0.961133  1.151548
# Emilia-Romagna                         1.643606  1.611092  1.606756  1.181290
# ...

# %%
dati_regionale_standardizzato = dati_regionale.apply(preprocessing.scale, axis = 0) # applico la standardizzazione a tutte le colonne
dati_regionale_standardizzato
# Out:
# 4                                        2006.0    2007.0    2008.0    2009.0  \
# REGIONI E \nRIPARTIZIONI\nGEOGRAFICHE
# Piemonte                               0.468592  0.961988  0.392165 -0.432213
# Valle d'Aosta/Vallée d'Aoste           1.238669  1.837945  3.192218  2.695289
# Liguria                               -1.647533 -0.870669 -1.295877 -1.815701
# Lombardia                             -0.135398  0.257536 -0.013888 -0.603992
# Trentino-Alto Adige/Südtirol          -0.393059 -1.501633 -0.290596  0.722103
# Bolzano/Bozen                         -0.266453 -1.804980 -0.399910 -0.156323
# Trento                                -0.572173 -1.197652 -0.255223  1.627401
# Veneto                                -0.125445  1.202154  0.372623 -0.514677
# Friuli-Venezia Giulia                  0.527887  0.122767 -1.034071 -0.127266
# Emilia-Romagna                         0.023948  0.795765  0.944838 -0.025200
# ...

# %%
#possiamo prendere una colonna (l'ultima della serie storica, oppure calcolare la media, oppure calcolcare la variazione percentuale)
# la porteremo dietro per il calcolo del super indice.

# %%
'''

invece di usare tutti i passaggi possiamo usare una libreria costruita ad hoc per nascondere la compelessità


'''
# Out:
# '\n\ninvece di usare tutti i passaggi possiamo usare una libreria costruita ad hoc per nascondere la compelessità\n\n\n'

# %%
from corso_lib import seleziona_dataset, pulitura_dataset, seleziona_sottotabella, inserisci_indice

# %%
titolo = "Proporzione standardizzata di persone di 14 anni e più che non praticano alcuna attività fisica per sesso, regione e ripartizione geografica - Anni 2005-2015"
dataset___att_fisica = seleziona_dataset(os.path.join(os.getcwd(), "Appendice-statistica-2016", "01.Salute", "Cap_01_Salute 13.xlsx"), "REG totale")
dataset___att_fisica
# Out:
#                                            Unnamed: 0   Unnamed: 1  \
# 0                                                 NaN          NaN
# 1   Tavola 13.1 segue - Proporzione standardizzata...          NaN
# 2                                      regione e r...          NaN
# 3                                                 NaN          NaN
# 4               REGIONI E \nRIPARTIZIONI\nGEOGRAFICHE  2005.000000
# 5                                                 NaN          NaN
# 6                                                 NaN          NaN
# 7                                                 NaN          NaN
# 8                                                 NaN          NaN
# 9                                    MASCHI E FEMMINE          NaN
# 10                                                NaN          NaN
# 11                                           Piemonte    34.782347
# 12                       Valle d'Aosta/Vallée d'Aoste    38.788545
# ...

# %%
dataset___att_fisica_pulito = pulitura_dataset(dataset___att_fisica, 4)
dataset___att_fisica_pulito
# Out:
# 4  REGIONI E \nRIPARTIZIONI\nGEOGRAFICHE     2005.0     2006.0     2007.0  \
# 11                              Piemonte  34.782347  34.592277  30.184073
# 12          Valle d'Aosta/Vallée d'Aoste  38.788545  31.623438  29.110754
# 13                               Liguria  40.392541  32.916890  41.555274
# 14                             Lombardia  30.959663  32.185900  33.551072
# 15          Trentino-Alto Adige/Südtirol  17.961836  17.594343  15.211894
# 16                         Bolzano/Bozen  17.351876  15.931336  14.534334
# 17                                Trento  18.546836  19.200806  15.865104
# 18                                Veneto  25.385242  29.908706  25.768490
# 19                 Friuli-Venezia Giulia  25.402107  30.562732  31.269974
# 20                        Emilia-Romagna  31.576967  30.794198  30.594616
# 21                               Toscana  34.999741  36.417462  33.972909
# 22                                Umbria  41.413825  44.361501  43.223916
# ...

# %%
dataset___att_fisica_pulito = seleziona_sottotabella(dataset___att_fisica_pulito, None)
dataset___att_fisica_pulito
# Out:
# 4  REGIONI E \nRIPARTIZIONI\nGEOGRAFICHE     2005.0     2006.0     2007.0  \
# 11                              Piemonte  34.782347  34.592277  30.184073
# 12          Valle d'Aosta/Vallée d'Aoste  38.788545  31.623438  29.110754
# 13                               Liguria  40.392541  32.916890  41.555274
# 14                             Lombardia  30.959663  32.185900  33.551072
# 15          Trentino-Alto Adige/Südtirol  17.961836  17.594343  15.211894
# 16                         Bolzano/Bozen  17.351876  15.931336  14.534334
# 17                                Trento  18.546836  19.200806  15.865104
# 18                                Veneto  25.385242  29.908706  25.768490
# 19                 Friuli-Venezia Giulia  25.402107  30.562732  31.269974
# 20                        Emilia-Romagna  31.576967  30.794198  30.594616
# 21                               Toscana  34.999741  36.417462  33.972909
# 22                                Umbria  41.413825  44.361501  43.223916
# ...

# %%
dataset___att_fisica_pulito_index = inserisci_indice(dataset___att_fisica_pulito)
dataset___att_fisica_pulito_index
# Out:
# 4                                         2005.0     2006.0     2007.0  \
# REGIONI E \nRIPARTIZIONI\nGEOGRAFICHE
# Piemonte                               34.782347  34.592277  30.184073
# Valle d'Aosta/Vallée d'Aoste           38.788545  31.623438  29.110754
# Liguria                                40.392541  32.916890  41.555274
# Lombardia                              30.959663  32.185900  33.551072
# Trentino-Alto Adige/Südtirol           17.961836  17.594343  15.211894
# Bolzano/Bozen                          17.351876  15.931336  14.534334
# Trento                                 18.546836  19.200806  15.865104
# Veneto                                 25.385242  29.908706  25.768490
# Friuli-Venezia Giulia                  25.402107  30.562732  31.269974
# Emilia-Romagna                         31.576967  30.794198  30.594616
# Toscana                                34.999741  36.417462  33.972909
# Umbria                                 41.413825  44.361501  43.223916
# ...

# %%
 dataset___att_fisica_pulito.loc[["Nord", "Mezzogiorno", "Centro "]].T.plot(figsize = (20,10), title= titolo ) #trasponi la tabella e mostra il grafico

# %%
#oppure in un unica funzione
from corso_lib import restituisci_dataset

unico_passaggio = restituisci_dataset(
    posizione_del_dataset = os.path.join(os.getcwd(), os.path.join(os.getcwd(), "Appendice-statistica-2016", "01.Salute", "Cap_01_Salute 13.xlsx")),
    nome_del_foglio = "REG totale", #inserire il nome del foglio
    riga_intestazione_colonna = 4, # inserire la riga in cui è presente l'intestazione di colonna 
    riga_sottotabella= None, # None - da divisione fra le due tabelle "maschi - femmine" dovrebbe cadere intorno alla riga 36
    tabella = None # None - qui si può mettere "maschi" - "femmine"
)

# %%
unico_passaggio
# Out:
# 4                                         2005.0     2006.0     2007.0  \
# REGIONI E \nRIPARTIZIONI\nGEOGRAFICHE
# Piemonte                               34.782347  34.592277  30.184073
# Valle d'Aosta/Vallée d'Aoste           38.788545  31.623438  29.110754
# Liguria                                40.392541  32.916890  41.555274
# Lombardia                              30.959663  32.185900  33.551072
# Trentino-Alto Adige/Südtirol           17.961836  17.594343  15.211894
# Bolzano/Bozen                          17.351876  15.931336  14.534334
# Trento                                 18.546836  19.200806  15.865104
# Veneto                                 25.385242  29.908706  25.768490
# Friuli-Venezia Giulia                  25.402107  30.562732  31.269974
# Emilia-Romagna                         31.576967  30.794198  30.594616
# Toscana                                34.999741  36.417462  33.972909
# Umbria                                 41.413825  44.361501  43.223916
# ...
